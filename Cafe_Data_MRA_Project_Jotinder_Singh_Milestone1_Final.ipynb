# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import missingno as msno

# %%
df=pd.read_excel('Cafe_Data_MRA.xlsx')

# %%
df.describe()
# Out:
#        Quantity      Rate       Tax  Discount     Total
# count 145830.00 145830.00 145830.00 145830.00 145830.00
# mean       1.12    161.78     48.93      0.10    224.96
# std        0.48    102.24     40.27      3.72    164.96
# min        1.00      0.01      0.00      0.00      0.01
# 25%        1.00     95.00     22.56      0.00    117.56
# 50%        1.00    125.00     32.06      0.00    167.06
# 75%        1.00    225.00     72.00      0.00    315.00
# max       30.00   2100.00   2731.25    825.00  14231.25

# %%
df.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate   Tax  Discount  Total  Category
# 0  50.00 11.88      0.00  61.88  BEVERAGE
# 1 100.00 23.75      0.00 123.75  BEVERAGE
# 2  40.00  9.50      0.00  49.50  BEVERAGE
# 3  50.00 11.88      0.00  61.88  BEVERAGE
# 4  45.00 10.69      0.00  55.69  BEVERAGE

# %%
msno.matrix(df,color=(0.99,0.81,0.37))

# %%
import os

from os import path
from wordcloud import WordCloud

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, 'sampleWords.txt')).read()

# Generate a word cloud image
wordcloud = WordCloud(background_color='white').generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40,background_color='white').generate(text)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()

# %%
df.groupby(['Bill Number ']).sum()
# Out:
#               Quantity   Rate     Tax  Discount   Total
# Bill Number
# G0470109             1   95.0   22.56       0.0  117.56
# G0470110             1  245.0   78.40       0.0  323.40
# G0470111             4  400.0   95.00       0.0  495.00
# G0470112             2  295.0   90.28       0.0  385.28
# G0470113             1  245.0   78.40       0.0  323.40
# ...                ...    ...     ...       ...     ...
# N0034042             2  350.0   98.88       0.0  448.88
# N0034043             3  150.0  140.63       0.0  590.63
# N0034044             4  150.0  187.50       0.0  787.50
# N0034045             2  150.0   93.75       0.0  393.75
# N0034046             1  250.0   78.13       0.0  328.13
#
# [69982 rows x 5 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.groupby(['Bill Number ']).sum().sum()
# Out:
# Quantity     163519.00
# Rate       23592706.87
# Tax         7135324.90
# Discount      13865.38
# Total      32805895.27
# dtype: float64

# %% [markdown]
# ## Total Number of Transactions - 69982

# %%
df.groupby(['Bill Number ']).mean()
# Out:
#               Quantity   Rate     Tax  Discount   Total
# Bill Number
# G0470109           1.0   95.0   22.56       0.0  117.56
# G0470110           1.0  245.0   78.40       0.0  323.40
# G0470111           1.0  100.0   23.75       0.0  123.75
# G0470112           1.0  147.5   45.14       0.0  192.64
# G0470113           1.0  245.0   78.40       0.0  323.40
# ...                ...    ...     ...       ...     ...
# N0034042           1.0  175.0   49.44       0.0  224.44
# N0034043           3.0  150.0  140.63       0.0  590.63
# N0034044           4.0  150.0  187.50       0.0  787.50
# N0034045           2.0  150.0   93.75       0.0  393.75
# N0034046           1.0  250.0   78.13       0.0  328.13
#
# [69982 rows x 5 columns]

# %%
df.groupby(['Bill Number ']).mean().mean()
# Out:
# Quantity     1.14
# Rate       177.61
# Tax         55.83
# Discount     0.09
# Total      250.23
# dtype: float64

# %%
df.sort_values(by='Discount',ascending=False)[0:50]
# Out:
#              Date Bill Number                              Item Desc  \
# 112474 2010-10-24     N0031090        STELLA ARTOIS (GLS)
# 34677  2011-01-02     G0518491        CHEESE FONDUE
# 75475  2011-01-02     G0518491        LEMON INFUSED CHAR GRILLED VEG
# 20061  2011-01-02     G0518491        ASSORTED TAPAS(2 )VEG
# 92655  2011-01-02     G0518491        ORANGE ARRABIATA
# 43234  2011-01-02     G0518491        PHILLYCREAM CHEESE &CHILLY PAN
# 2466   2010-09-16     N0030525        1+1 WINE GLASS
# 113588 2010-05-26     G0478920        RED BULL 2+1
# 43282  2011-01-02     G0518432        CH COFFEE MUGS
# 74834  2010-11-16     G0509163        QUA  MINERAL WATER(1000ML)
# 24001  2010-11-07     N0031314        CARLSBERG
# 71638  2011-02-16     N0033320        TUBORG
# 47636  2011-03-05     G0529798        3 RED BULL
# 43233  2011-01-02     G0518491        GARDEN FRESH PANINI
# 43232  2011-01-02     G0518491        B.M.T. PANINI
# 43075  2011-01-02     G0518491        PINK LEMONADE
# ...

# %%
df.sort_values(by='Discount',ascending=False)[0:50].groupby('Bill Number ').sum().sort_values(
    by='Discount',ascending=False)
# Out:
#               Quantity    Rate     Tax  Discount   Total
# Bill Number
# G0518491            53 1590.00 1197.01   2160.00 8397.01
# N0031090            11  250.00  601.56    825.00 3351.56
# G0478920             4  615.00   27.31    500.00  642.31
# G0509163             7  215.00    0.00    415.00  415.00
# G0518432             3  391.00    0.00    391.00  391.00
# G0526857             3 1200.00  268.80    360.00 1468.80
# N0031314             6  520.00  218.75    300.00 1218.75
# G0529798             4  420.00  139.65    252.00  979.65
# G0524587             2  250.00    0.00    250.00  250.00
# G0503248             2  240.00    0.00    240.00  240.00
# N0031031             3  575.00  151.20    225.00  901.20
# N0030525             1  220.00    0.00    220.00  220.00
# N0033320             6  100.00  131.25    180.00  731.25
# G0507708             3  400.00   87.28    157.50  612.28
# G0479389             1  150.00    0.00    150.00  150.00
# ...

# %% [markdown]
# ## Most discount i.e. 2160 was provided for one Bill Number i.e. G0518491, which seems like a one of instance and it might skew the rest of the data set. Hence we drop this Bill Number from the data set.

# %%
df_org=df.copy()

# %%
df.drop(df[df['Bill Number '] == 'G0518491'].index,inplace=True)

# %%
df[df['Bill Number '] == 'G0518491']
# Out:
# Empty DataFrame
# Columns: [Date, Bill Number , Item Desc, Time, Quantity, Rate, Tax, Discount, Total, Category]
# Index: []

# %% [markdown]
# ## Bill Number G0518491 dropped successfully

# %%
df.shape
# Out:
# (145815, 10)

# %% [markdown]
# ### 15 rows dropped

# %%
df.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate   Tax  Discount  Total  Category
# 0  50.00 11.88      0.00  61.88  BEVERAGE
# 1 100.00 23.75      0.00 123.75  BEVERAGE
# 2  40.00  9.50      0.00  49.50  BEVERAGE
# 3  50.00 11.88      0.00  61.88  BEVERAGE
# 4  45.00 10.69      0.00  55.69  BEVERAGE

# %%
df[df['Discount']==df['Total']]
# Out:
#              Date Bill Number                        Item Desc      Time  \
# 2466   2010-09-16     N0030525  1+1 WINE GLASS                  23:59:29
# 28227  2010-09-28     G0501036  BLUEBERRY BRAIN FREEZER SHAKE   00:53:47
# 37242  2010-10-11     G0503248  KIT KAT SHAKE                   00:13:51
# 37243  2010-10-11     G0503248  GARDEN FRESH PANINI             00:13:51
# 38944  2010-06-12     G0481639  QUA  MINERAL WATER(1000ML)      01:16:34
# 38945  2010-06-12     G0481639  QUA  MINERAL WATER(1000ML)      01:16:34
# 43279  2011-01-02     G0518432  MUGS - CHIP PRINT               19:48:49
# 43280  2011-01-02     G0518432  MUGS - DOTS                     19:48:49
# 43281  2011-01-02     G0518432  MUGS - STRIPE PLAIN             19:48:49
# 43282  2011-01-02     G0518432  CH COFFEE MUGS                  19:48:49
# 46068  2011-02-04     G0524587  APPLE PIE SHAKE                 23:13:50
# 46069  2011-02-04     G0524587  SATAY CHICKEN PANINI            23:13:50
# ...

# %% [markdown]
# ## Removing rows where Bill Amount is the same as Discount, as these might have been part of a promotional offer or might have been billed on the house

# %%
df.drop(df[df['Discount']==df['Total']].index,inplace=True)

# %%
df.shape
# Out:
# (145798, 10)

# %% [markdown]
# ## 17 Rows dropped

# %%
df.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate   Tax  Discount  Total  Category
# 0  50.00 11.88      0.00  61.88  BEVERAGE
# 1 100.00 23.75      0.00 123.75  BEVERAGE
# 2  40.00  9.50      0.00  49.50  BEVERAGE
# 3  50.00 11.88      0.00  61.88  BEVERAGE
# 4  45.00 10.69      0.00  55.69  BEVERAGE

# %%
df.groupby(by='Date').mean()
# Out:
#             Quantity   Rate   Tax  Discount  Total
# Date
# 2010-04-01      1.12 143.92 42.66      0.00 198.63
# 2010-04-02      1.18 149.21 45.58      0.00 213.58
# 2010-04-03      1.21 151.76 46.99      0.19 222.37
# 2010-04-04      1.13 148.54 44.78      0.00 208.92
# 2010-04-05      1.12 159.82 47.42      0.14 219.98
# ...              ...    ...   ...       ...    ...
# 2011-03-27      1.14 178.17 53.52      0.09 248.71
# 2011-03-28      1.13 176.07 54.66      0.00 248.15
# 2011-03-29      1.09 163.44 47.72      0.00 222.51
# 2011-03-30      1.22 197.73 67.54      1.09 311.94
# 2011-03-31      1.08 161.89 46.68      0.00 218.68
#
# [365 rows x 5 columns]

# %%
df.groupby(by='Date').mean().index
# Out:
# DatetimeIndex(['2010-04-01', '2010-04-02', '2010-04-03', '2010-04-04',
#                '2010-04-05', '2010-04-06', '2010-04-07', '2010-04-08',
#                '2010-04-09', '2010-04-10',
#                ...
#                '2011-03-22', '2011-03-23', '2011-03-24', '2011-03-25',
#                '2011-03-26', '2011-03-27', '2011-03-28', '2011-03-29',
#                '2011-03-30', '2011-03-31'],
#               dtype='datetime64[ns]', name='Date', length=365, freq=None)

# %% [markdown]
# ## Average Rate over 365 days

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x=df.groupby(by='Date').mean().index,
             y=df.groupby(by='Date').mean()['Rate'])

# %% [markdown]
# ## Average Rate of FOOD over 365 days

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x=df[df['Category'] == 'FOOD'].groupby(by='Date').mean().index,
             y=df.groupby(by='Date').mean()['Rate'])

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x=df[df['Category'] == 'LIQUOR'].groupby(by='Date').mean().index,
             y=df[df['Category'] == 'LIQUOR'].groupby(by='Date').mean()['Rate'])

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x=df[df['Category'] == 'TOBACCO'].groupby(by='Date').mean().index,
             y=df[df['Category'] == 'TOBACCO'].groupby(by='Date').mean()['Rate'])

# %%
df.shape
# Out:
# (145798, 10)

# %%
df.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate   Tax  Discount  Total  Category
# 0  50.00 11.88      0.00  61.88  BEVERAGE
# 1 100.00 23.75      0.00 123.75  BEVERAGE
# 2  40.00  9.50      0.00  49.50  BEVERAGE
# 3  50.00 11.88      0.00  61.88  BEVERAGE
# 4  45.00 10.69      0.00  55.69  BEVERAGE

# %%
df.to_excel('Cafe_Data_MRA_Newest1.xlsx')
